# %% [markdown]
# # Task 6 Bonus
#
# ### Author: Mee Vang Date:09/24/23

# %% [markdown]
# ### Use panda to read Caffeine dataset csv file

# %%
import pandas as pd

caff = pd.read_csv(r"C:\Users\mvang\NW Week 5\datafun-05-data-at-rest\caffeine.csv")

print(caff)
# Out:
#                            drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                   Costa Coffee   256.993715         0            277  Coffee
# 1    Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2             Hell Energy Coffee   250.191810       150            100  Coffee
# 3             Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                   Nescafe Gold   250.191810         0             66  Coffee
# ..                           ...          ...       ...            ...     ...
# 605     Pep Talk Sparkling Water   354.882000         0             55   Water
# 606          Polar Seltzer Water   354.882000         0              0   Water
# 607       Yerbae Sparkling Water   354.882000         0            100   Water
# 608                  Tonic Water   295.735000       110              0   Water
# 609    MiO Energy Water Enhancer   236.588000         0             60   Water
#
# [610 rows x 5 columns]

# %% [markdown]
# ### View the head of the file.

# %%
caff.head(10)
# Out:
#                             drink  Volume (ml)  Calories  Caffeine (mg)  \
# 0                    Costa Coffee   256.993715         0            277
# 1     Coffee Friend Brewed Coffee   250.191810         0            145
# 2              Hell Energy Coffee   250.191810       150            100
# 3              Killer Coffee (AU)   250.191810         0            430
# 4                    Nescafe Gold   250.191810         0             66
# 5                Espresso Monster   248.417400       170            160
# 6  Dunkin Donuts Shot In The Dark   239.545350        80            134
# 7                Illy Issimo Cafe   201.099800        45            155
# 8   Starbucks Doubleshot Espresso   192.227750       140            120
# 9    TrueStart Performance Coffee   150.824850         0             95
#
#      type
# 0  Coffee
# 1  Coffee
# 2  Coffee
# 3  Coffee
# 4  Coffee
# 5  Coffee
# 6  Coffee
# 7  Coffee
# 8  Coffee
# 9  Coffee

# %% [markdown]
# ### Rename the columns and view the head of the file.

# %%
caff.columns = ['Name', 'Volume (ml)', 'Calories', 'Caffeine (mg)', 'Type']

caff.head(10)
# Out:
#                              Name  Volume (ml)  Calories  Caffeine (mg)  \
# 0                    Costa Coffee   256.993715         0            277
# 1     Coffee Friend Brewed Coffee   250.191810         0            145
# 2              Hell Energy Coffee   250.191810       150            100
# 3              Killer Coffee (AU)   250.191810         0            430
# 4                    Nescafe Gold   250.191810         0             66
# 5                Espresso Monster   248.417400       170            160
# 6  Dunkin Donuts Shot In The Dark   239.545350        80            134
# 7                Illy Issimo Cafe   201.099800        45            155
# 8   Starbucks Doubleshot Espresso   192.227750       140            120
# 9    TrueStart Performance Coffee   150.824850         0             95
#
#      Type
# 0  Coffee
# 1  Coffee
# 2  Coffee
# 3  Coffee
# 4  Coffee
# 5  Coffee
# 6  Coffee
# 7  Coffee
# 8  Coffee
# 9  Coffee

# %% [markdown]
# ### Use the DataFrame describe() function to calculate basic descriptive statistics.

# %%
caff.describe()
# Out:
#        Volume (ml)    Calories  Caffeine (mg)
# count   610.000000  610.000000     610.000000
# mean    346.543630   75.527869     134.693443
# std     143.747738   94.799919     155.362861
# min       7.393375    0.000000       0.000000
# 25%     236.588000    0.000000      50.000000
# 50%     354.882000   25.000000     100.000000
# 75%     473.176000  140.000000     160.000000
# max    1419.528000  830.000000    1555.000000

# %% [markdown]
# ### Use the DataFrame hist() function to generate histograms for all numeric columns.

# %%
# %matplotlib inline

histogram = caff.hist()
